# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowsalya-2006/Data-Analysis-Using-Python-Project/blob/main/DAY_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
marks = np.array([98,56,68,67])
print(marks[2])
# Out:
# 68

# %% [markdown]
# Indexing & Slicing

# %%
import numpy as np
marks = np.array([45,67,89,80])
print(marks[1:4])
# Out:
# [67 89 80]

# %% [markdown]
# Reshape & Transpose

# %%
import numpy as np
a = np.array([1,2,3,4,5,6])
b = arr.reshape(2,3)
print(b)
c=b.transpose()
print("\n",c)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# AGGEREGATION & AXIS OPERATION

# %%
import numpy as np
marks = np.array([79,88,78,60])
average = np.mean(marks)
print(average)
# Out:
# 78.5

# %%
import numpy as np
salary=np.array([10000,20000,30000,40000,50000])
med=np.median(salary)
print(med)

# %%
total=np.sum(marks)
print(total)
