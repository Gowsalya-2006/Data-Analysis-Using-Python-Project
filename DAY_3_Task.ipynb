# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowsalya-2006/Data-Analysis-Using-Python-Project/blob/main/DAY_3_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pratice 1:Student score analysis

# %%
scores = [78,85,92,67,88]

total = sum(scores)
average = total/len(scores)
highest = max(scores)
lowest = min(scores)

print("Student Scores:",scores)
print("Total Marks:",total)
print("Average Marks:",average)
print("Highest Marks:",highest)
print("Lowest Marks:",lowest)
# Out:
# Student Scores: [78, 85, 92, 67, 88]
# Total Marks: 410
# Average Marks: 82.0
# Highest Marks: 92
# Lowest Marks: 67

# %% [markdown]
# pratice 2:Sales Array Calculation

# %%
sales = [12000,15000,18000,14000,20000]

total_sales = sum(sales)
average_sales = total/len(sales)
highest_sales = max(sales)
lowest_sales = min(sales)

print("Monthly Sales:",sales)
print("Total Saales:",total_sales)
print("Average Sales:",average_sales)
print("Highest Sales:",highest_sales)
print("Lowest Sales:",lowest_sales)
# Out:
# Monthly Sales: [12000, 15000, 18000, 14000, 20000]
# Total Saales: 79000
# Average Sales: 82.0
# Highest Sales: 20000
# Lowest Sales: 12000
