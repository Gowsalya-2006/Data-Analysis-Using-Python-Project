# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowsalya-2006/Data-Analysis-Using-Python-Project/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Function

# %%
# user defined function
def demo():
  print("heloo")
demo()
# Out:
# heloo

# %%
# with parameter
def student(name):
  print("heloo",name)
student("arthi")
# Out:
# heloo arthi

# %%
# return function

def add(a,b):
  return a+b
x = add(5,6)
print(x)
# Out:
# 11
